# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("customer.csv")

# %%
df.sample(5)
# Out:
#     age  gender   review education purchased
# 34   86    Male  Average    School        No
# 17   22  Female     Poor        UG       Yes
# 14   15    Male     Poor        PG       Yes
# 10   98  Female     Good        UG       Yes
# 5    31  Female  Average    School       Yes

# %%
df=df.iloc[1:,2:3]

# %%
df
# Out:
#      review education purchased
# 0   Average    School        No
# 1      Poor        UG        No
# 2      Good        PG        No
# 3      Good        PG        No
# 4   Average        UG        No
# 5   Average    School       Yes
# 6      Good    School        No
# 7      Poor    School       Yes
# 8   Average        UG        No
# 9      Good        UG       Yes
# 10     Good        UG       Yes
# 11     Good        UG       Yes
# 12     Poor    School        No
# 13  Average    School        No
# 14     Poor        PG       Yes
# 15     Poor        UG        No
# 16     Poor        UG       Yes
# 17     Poor        UG       Yes
# 18     Good    School        No
# 19     Poor        PG       Yes
# 20  Average    School       Yes
# 21  Average        PG        No
# 22     Poor        PG       Yes
# 23     Good    School        No
# 24  Average        PG       Yes
# 25     Good    School        No
# 26     Poor        PG        No
# 27     Poor        PG        No
# ...

# %%
# from sklearn.model_selection import train_test_split
# X_train,X_test,y_train,y_test=train_test_split(df.iloc[1:,2:3],df.iloc[:,:2],test_size=0.2)

# %%
# from sklearn.model_selection import train_test_split
# X_train,X_test,y_train,y_test=train_test_split(df,test_size=0.2,
#     train_size=0.2,
#     random_state=True,
#     shuffle=True,
#     stratify=None,
# )

# %%
# from sklearn.model_selection import train_test_split

# # Check the shape of the DataFrame
# print("DataFrame shape:", df.shape)

# # Ensure df has the required number of columns


# # Correct split assuming you want to use the first column as X and the second column as y
# X = df.iloc[:,0:2]  # Feature columns
# y = df.iloc[:,:-1]    # Target column

# # Split the DataFrame
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# # Verify the split
# print("X_train shape:", X_train.shape)
# print("X_test shape:", X_test.shape)
# print("y_train shape:", y_train.shape)
# print("y_test shape:", y_test.shape)

# %%
X_train
# Out:
# Empty DataFrame
# Columns: []
# Index: [32, 47, 15, 40, 24, 12, 30, 16, 41, 8, 20, 18, 35, 44, 42, 22, 45, 17, 6, 27, 28, 21, 4, 10, 25, 43, 49, 31, 39, 34, 38, 13, 26, 2, 14, 46, 37, 5]

# %%
X_test
# Out:
# Empty DataFrame
# Columns: []
# Index: [33, 3, 48, 11, 19, 7, 36, 9, 29, 23]

# %%
y_train
# Out:
# Empty DataFrame
# Columns: []
# Index: [32, 47, 15, 40, 24, 12, 30, 16, 41, 8, 20, 18, 35, 44, 42, 22, 45, 17, 6, 27, 28, 21, 4, 10, 25, 43, 49, 31, 39, 34, 38, 13, 26, 2, 14, 46, 37, 5]

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('customer.csv')

# %%
df.sample(5)
# Out:
#     age  gender   review education purchased
# 47   38  Female     Good        PG       Yes
# 30   73    Male  Average        UG        No
# 48   39  Female     Good        UG       Yes
# 4    16  Female  Average        UG        No
# 43   27    Male     Poor        PG        No

# %%
df = df.iloc[:,2:]

# %%
df.head()
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No
# 2     Good        PG        No
# 3     Good        PG        No
# 4  Average        UG        No

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X_train
# Out:
# Empty DataFrame
# Columns: []
# Index: [32, 47, 15, 40, 24, 12, 30, 16, 41, 8, 20, 18, 35, 44, 42, 22, 45, 17, 6, 27, 28, 21, 4, 10, 25, 43, 49, 31, 39, 34, 38, 13, 26, 2, 14, 46, 37, 5]

# %%
oe = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# %%
oe.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 oe.fit(X_train)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:1303, in OrdinalEncoder.fit(self, X, y)
#    1296     raise TypeError(
#    1297         "unknown_value should only be set when "
#    1298         "handle_unknown is 'use_encoded_value', "
#    1299         f"got {self.unknown_value}."
#    1300     )
#    1302 # `_fit` will only raise an error when `self.handle_unknown="error"`
# -> 1303 self._fit(X, handle_unknown=self.handle_unknown, force_all_finite="allow-nan")
#    1305 cardinalities = [len(categories) for categories in self.categories_]
#    1307 # stores the missing indices per category
#
# ...

# %%
X_train
# Out:
# Empty DataFrame
# Columns: []
# Index: [32, 47, 15, 40, 24, 12, 30, 16, 41, 8, 20, 18, 35, 44, 42, 22, 45, 17, 6, 27, 28, 21, 4, 10, 25, 43, 49, 31, 39, 34, 38, 13, 26, 2, 14, 46, 37, 5]

# %%
oe.categories_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 oe.categories_
#
# AttributeError: 'OrdinalEncoder' object has no attribute 'categories_'

# %%
X_train
# Out:
# Empty DataFrame
# Columns: []
# Index: [32, 47, 15, 40, 24, 12, 30, 16, 41, 8, 20, 18, 35, 44, 42, 22, 45, 17, 6, 27, 28, 21, 4, 10, 25, 43, 49, 31, 39, 34, 38, 13, 26, 2, 14, 46, 37, 5]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
LabelEncoder()
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 le.classes_
#
# AttributeError: 'LabelEncoder' object has no attribute 'classes_'

# %%
y_train = le.transform(y_train)
y_test = le.transform(y_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 y_train = le.transform(y_train)
#       2 y_test = le.transform(y_test)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:133, in LabelEncoder.transform(self, y)
#     120 def transform(self, y):
# ...
